# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "source": [
    "# 🧵 Metin İşlemleri ve Kaçış Karakterleri\n",
    "\n",
    "Python'da metinler (String) tırnak içinde yazılır. Bazı özel durumlarda ters eğik çizgi (`\\`) kullanarak bilgisayara özel komutlar veririz."
   ]
  },
  {
   "cell_type": "markdown",
   "source": [
    "### ⚡ En Çok Kullanılan Kaçış Karakterleri\n",
    "* `\\n`: **New Line.** Metni bir alt satıra atar.\n",
    "* `\\t`: **Tab.** Bir tab boşluk (4 karakter) bırakır.\n",
    "* `\\'` veya `\\\"`: Metin içindeki tırnak işaretlerini Python'un karıştırmasını engeller.\n",
    "\n",
    "### 🛡️ Raw Strings (r\"\")\n",
    "Eğer metnin başındaki tırnaktan önce `r` harfi koyarsan, Python içindeki hiçbir kaçış karakterini çalıştırmaz. Bu özellikle dosya yolları için çok önemlidir."
   ]
  },
  {
   "cell_type": "code",
   "source": [
    "print(\"Satır 1\\nSatır 2\") # Alt alta yazar\n",
    "print(\"Kategori:\\tElektronik\") # Boşluk bırakır\n",
    "\n",
    "# Raw string farkı\n",
    "print(\"C:\\new_folder\\test\")    # \\n olduğu için alt satıra geçer (Hatalı olur)\n",
    "print(r\"C:\\new_folder\\test\")   # r sayesinde olduğu gibi yazar (Doğru)"
   ]
  }
 ],
 "metadata": { "kernelspec": { "display_name": "Python 3", "name": "python3" }, "language_info": { "name": "python" } },
 "nbformat": 4, "nbformat_minor": 5
}
