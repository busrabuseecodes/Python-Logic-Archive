# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "source": [
    "# 📊 Temel Veri Tipleri\n",
    "\n",
    "Python'da her verinin bir tipi vardır. Bir verinin tipini öğrenmek için `type()` fonksiyonunu kullanırız."
   ]
  },
  {
   "cell_type": "markdown",
   "source": [
    "### 1. Integer (int)\n",
    "Tam sayılardır. Örn: `10`, `-5`, `0`.\n",
    "\n",
    "### 2. Float (float)\n",
    "Ondalıklı sayılardır. Python'da virgül yerine nokta (`.`) kullanılır. Örn: `3.14`, `10.0`.\n",
    "\n",
    "### 3. String (str)\n",
    "Metinsel ifadelerdir. Tırnak içinde yazılırlar. Örn: `\"Merhaba\"`.\n",
    "\n",
    "### 4. Boolean (bool)\n",
    "Mantıksal değerlerdir. Sadece iki seçenek vardır: `True` veya `False`."
   ]
  },
  {
   "cell_type": "code",
   "source": [
    "sayi = 25\n",
    "pi = 3.14\n",
    "mesaj = \"Python\"\n",
    "durum = True\n",
    "\n",
    "print(type(sayi))  # <class 'int'>\n",
    "print(type(pi))    # <class 'float'>\n",
    "print(type(mesaj)) # <class 'str'>\n",
    "print(type(durum)) # <class 'bool'>"
   ]
  }
 ],
 "metadata": { "kernelspec": { "display_name": "Python 3", "name": "python3" }, "language_info": { "name": "python" } },
 "nbformat": 4, "nbformat_minor": 5
}
