# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "source": [
    "# 📦 Değişken Tanımlama ve İsimlendirme Kuralları\n",
    "\n",
    "Python'da verileri hafızada tutmak için değişkenleri kullanırız. Ancak her ismi kafamıza göre veremeyiz. İşte hayati kurallar:"
   ]
  },
  {
   "cell_type": "markdown",
   "source": [
    "### 🚫 1. Rakamla Başlayamaz\n",
    "Değişken isimleri harf veya alt tire (`_`) ile başlamalıdır.\n",
    "* `1sayi = 10` ❌ (Hata verir)\n",
    "* `sayi1 = 10` ✅ (Doğru)\n",
    "\n",
    "### 🚫 2. Boşluk İçeremez\n",
    "Birden fazla kelime kullanacaksan alt tire kullanmalısın (snake_case).\n",
    "* `kullanici adi = \"Ali\"` ❌\n",
    "* `kullanici_adi = \"Ali\"` ✅\n",
    "\n",
    "### 🚫 3. Özel Karakterler Yasaktır\n",
    "`@, $, %, &, !, +` gibi işaretler isimlerde kullanılamaz. Sadece `_` serbesttir.\n",
    "\n",
    "### ⚠️ 4. Büyük/Küçük Harf Duyarlılığı (Case Sensitivity)\n",
    "Python için `elma`, `Elma` ve `ELMA` üç farklı değişkendir."
   ]
  },
  {
   "cell_type": "code",
   "source": [
    "# Örnek Çalışma\n",
    "ad = \"Büşra\"\n",
    "Ad = \"Zeynep\"\n",
    "\n",
    "print(ad)  # Çıktı: Büşra\n",
    "print(Ad)  # Çıktı: Zeynep"
   ]
  }
 ],
 "metadata": { "kernelspec": { "display_name": "Python 3", "name": "python3" }, "language_info": { "name": "python" } },
 "nbformat": 4, "nbformat_minor": 5
}
