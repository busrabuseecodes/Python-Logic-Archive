# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🧮 Math Kütüphanesi Pratikleri\n",
    "\n",
    "Python'da karmaşık matematiksel işlemler (karekök, yuvarlama, trigonometri) için `math` modülünü kullanırız. Bu modül, daha hassas sonuçlar almamızı sağlar."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 1. Sayı Yuvarlama İşlemleri\n",
    "Bazen ondalıklı sayıları en yakın tam sayıya veya her zaman yukarı/aşağı yuvarlamak isteriz:\n",
    "* `math.ceil()`: Sayıyı her zaman **yukarı** yuvarlar.\n",
    "* `math.floor()`: Sayıyı her zaman **aşağı** yuvarlar."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import math\n",
    "\n",
    "sayi = 4.2\n",
    "print(\"Yukarı yuvarla:\", math.ceil(sayi))   # Çıktı: 5\n",
    "print(\"Aşağı yuvarla:\", math.floor(sayi)) # Çıktı: 4"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 2. Karekök ve Üs Alma\n",
    "Python'da `**` operatörü ile üs alabiliriz ama `math` kütüphanesi daha spesifik fonksiyonlar sunar."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "print(\"81'in karekökü:\", math.sqrt(81))\n",
    "print(\"2 üzeri 5:\", math.pow(2, 5))"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 3. Sabit Değerler (Pi)\n",
    "Kendi yazdığımız `3.14` yerine kütüphanedeki gerçek değeri kullanmak hesaplamalarda hatayı sıfıra indirir."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "print(\"Pi Sayısı:\", math.pi)\n",
    "print(\"Euler Sayısı (e):\", math.e)"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10.0"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
