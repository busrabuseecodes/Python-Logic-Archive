# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "source": [
    "# 📐 Geometrik Hesaplamalar (Hacim ve Alan)\n",
    "\n",
    "Bu notebook, temel geometrik şekillerin alan ve hacim hesaplamalarını Python algoritmaları ile gerçekleştirmek için oluşturulmuştur."
   ]
  },
  {
   "cell_type": "markdown",
   "source": [
    "### 🏐 1. Küre Hacmi Hesaplama\n",
    "**Formül:** $$V = \\frac{4}{3} \\pi r^3$$\n",
    "\n",
    "Aşağıdaki kodda yarıçapı (`r`) 5 olan bir kürenin hacmini hesaplıyoruz."
   ]
  },
  {
   "cell_type": "code",
   "source": [
    "pi = 3.14\n",
    "r = 5\n",
    "hacim = (4/3) * pi * (r ** 3)\n",
    "\n",
    "print(\"Yarıçapı 5 olan kürenin hacmi:\", hacim)"
   ]
  },
  {
   "cell_type": "markdown",
   "source": [
    "### 📐 2. Yamuk Alanı Hesaplama\n",
    "**Formül:** $$A = \\frac{(a + b) \\cdot h}{2}$$\n",
    "\n",
    "Burada `a` alt taban, `b` üst taban ve `h` yüksekliktir."
   ]
  },
  {
   "cell_type": "code",
   "source": [
    "alt_taban = 10\n",
    "ust_taban = 8\n",
    "yukseklik = 6\n",
    "alan = ((alt_taban + ust_taban) * yukseklik) / 2\n",
    "\n",
    "print(\"Yamuğun alanı:\", alan)"
   ]
  }
 ],
 "metadata": { "kernelspec": { "display_name": "Python 3", "name": "python3" }, "language_info": { "name": "python" } },
 "nbformat": 4, "nbformat_minor": 5
}
