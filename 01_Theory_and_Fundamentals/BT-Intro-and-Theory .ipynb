# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🏗️ Bilgisayar Bilimi ve Programlama Temelleri\n",
    "\n",
    "Bu çalışma, yazılım dünyasının temel kavramlarını ve çalışma prensiplerini anlamak amacıyla oluşturulmuş kişisel bir veri bankasıdır."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 💻 1. Donanım ve Yazılım Katmanları\n",
    "\n",
    "Bir bilgisayarın çalışması için iki temel yapı gerekir:\n",
    "* **Donanım (Hardware):** CPU (İşlemci), RAM (Bellek) ve Depolama birimleri gibi fiziksel parçalar.\n",
    "* **Yazılım (Software):** Donanıma ne yapması gerektiğini söyleyen kod bütünü."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## ⚙️ 2. Derleyici (Compiler) vs. Yorumlayıcı (Interpreter)\n",
    "\n",
    "Programlama dilleri makine diline iki şekilde çevrilir:\n",
    "\n",
    "1. **Derleyici:** Kodun tamamını bir kerede çevirir (Örn: C, C++).\n",
    "2. **Yorumlayıcı:** Kodu satır satır okur ve o an çalıştırır.\n",
    "\n",
    "**Not:** Python, **Yorumlanan (Interpreted)** bir dildir. Bu yüzden hata aldığımızda program o satıra gelene kadar çalışmaya devam eder."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# İlk Python denemesi\n",
    "print(\"Sistem kontrol ediliyor...\")\n",
    "print(\"Durum: Bağımsız ve hazır!\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 📝 3. Algoritma Mantığı\n",
    "\n",
    "Algoritma, bir problemi çözmek için izlenen adım adım yoldur. \n",
    "**Örnek:** Kullanıcıdan sayı al -> Çift mi bak -> Sonucu yazdır."
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10.0"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
