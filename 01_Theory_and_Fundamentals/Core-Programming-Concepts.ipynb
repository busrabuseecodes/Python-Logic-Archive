# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🧠 Temel Programlama Kavramları\n",
    "\n",
    "Bu dosya, Python ve genel programlama dillerinde kullanılan çekirdek terimleri ve çalışma prensiplerini içermektedir."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 💬 1. Yorum Satırları (Comments)\n",
    "\n",
    "Kodun içine kendimiz veya başkaları için not bırakmamızı sağlar. Python bu satırları çalıştırmaz.\n",
    "\n",
    "* **Tek satır:** `#` işareti ile başlar.\n",
    "* **Çok satır:** `\"\"\"` (Üç tırnak) arasına yazılır."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Bu bir yorum satırıdır, ekranda görünmez\n",
    "print(\"Yorum satırı testi başarılı!\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 🐞 2. Hata Ayıklama (Debugging)\n",
    "\n",
    "Programda oluşan mantıksal veya yazım hatalarını bulup düzeltme sürecidir.\n",
    "\n",
    "* **Syntax Error:** Yazım yanlışı (Örn: Parantezi kapatmamak).\n",
    "* **Logical Error:** Kod çalışır ama sonuç yanlıştır (Örn: Toplama yerine çıkarma yapmak)."
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 📊 3. Temel Veri Tipleri (Data Types)\n",
    "\n",
    "Bilgisayarın veriyi nasıl algıladığını belirler:\n",
    "\n",
    "* **Integer (int):** Tam sayılar (5, -10).\n",
    "* **Float:** Ondalıklı sayılar (3.14, 2.0).\n",
    "* **String (str):** Metinler (\"Merhaba\").\n",
    "* **Boolean (bool):** Mantıksal değerler (True, False)."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Veri tiplerini kontrol edelim\n",
    "print(type(10))    # <class 'int'>\n",
    "print(type(10.5))  # <class 'float'>\n",
    "print(type(\"Hi\"))  # <class 'str'>\n",
    "print(type(True))  # <class 'bool'>"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10.0"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
